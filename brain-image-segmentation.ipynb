# %% [markdown]
# # Image Segmentation using UNet

# %% [markdown]
# ## Import Libraries

# %%
import os
import random
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

import cv2
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
#from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Load Data

# %%
DataPath = "/kaggle/input/lgg-mri-segmentation/kaggle_3m/"

dirs = []
images = []
masks = []
for dirname, _, filenames in os.walk(DataPath):
    for filename in filenames:
        if 'mask'in filename:
            dirs.append(dirname.replace(DataPath, ''))
            masks.append(filename)
            images.append(filename.replace('_mask', ''))

# %%
print(masks[:10], images[:10])
# Out:
# ['TCGA_DU_7010_19860307_56_mask.tif', 'TCGA_DU_7010_19860307_8_mask.tif', 'TCGA_DU_7010_19860307_34_mask.tif', 'TCGA_DU_7010_19860307_33_mask.tif', 'TCGA_DU_7010_19860307_43_mask.tif', 'TCGA_DU_7010_19860307_39_mask.tif', 'TCGA_DU_7010_19860307_7_mask.tif', 'TCGA_DU_7010_19860307_31_mask.tif', 'TCGA_DU_7010_19860307_6_mask.tif', 'TCGA_DU_7010_19860307_38_mask.tif'] ['TCGA_DU_7010_19860307_56.tif', 'TCGA_DU_7010_19860307_8.tif', 'TCGA_DU_7010_19860307_34.tif', 'TCGA_DU_7010_19860307_33.tif', 'TCGA_DU_7010_19860307_43.tif', 'TCGA_DU_7010_19860307_39.tif', 'TCGA_DU_7010_19860307_7.tif', 'TCGA_DU_7010_19860307_31.tif', 'TCGA_DU_7010_19860307_6.tif', 'TCGA_DU_7010_19860307_38.tif']

# %%
len(dirs), len(images), len(masks)
# Out:
# (3929, 3929, 3929)

# %%
imagePath_df = pd.DataFrame({'directory':dirs, 'images': images, 'masks': masks})

# %%
imagePath_df.head()
# Out:
#                directory                        images  \
# 0  TCGA_DU_7010_19860307  TCGA_DU_7010_19860307_56.tif
# 1  TCGA_DU_7010_19860307   TCGA_DU_7010_19860307_8.tif
# 2  TCGA_DU_7010_19860307  TCGA_DU_7010_19860307_34.tif
# 3  TCGA_DU_7010_19860307  TCGA_DU_7010_19860307_33.tif
# 4  TCGA_DU_7010_19860307  TCGA_DU_7010_19860307_43.tif
#
#                                masks
# 0  TCGA_DU_7010_19860307_56_mask.tif
# 1   TCGA_DU_7010_19860307_8_mask.tif
# 2  TCGA_DU_7010_19860307_34_mask.tif
# 3  TCGA_DU_7010_19860307_33_mask.tif
# 4  TCGA_DU_7010_19860307_43_mask.tif

# %% [markdown]
# ## Image Shape

# %%
def print_imShape():
    idx = np.random.randint(0, len(imagePath_df))
    
    imagePath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['images'].iloc[idx])
    maskPath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['masks'].iloc[idx])
    
    image = cv2.imread(imagePath)
    mask = cv2.imread(maskPath)
    
    print(image.shape, mask.shape)

# %%
for i in range(5):
    print_imShape()
# Out:
# (256, 256, 3) (256, 256, 3)
# (256, 256, 3) (256, 256, 3)
# (256, 256, 3) (256, 256, 3)
# (256, 256, 3) (256, 256, 3)
# (256, 256, 3) (256, 256, 3)

# %% [markdown]
# ## Plot Images

# %%
def plot_images():
    idx = np.random.randint(0, len(imagePath_df))
    
    imagePath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['images'].iloc[idx])
    maskPath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['masks'].iloc[idx])
    
    image = cv2.imread(imagePath)
    mask = cv2.imread(maskPath)
    
    fig, axs = plt.subplots(1,3, figsize=[13,15])
    
    axs[0].imshow(image)
    axs[0].set_title('Brain MRI')
    
    axs[1].imshow(mask)
    axs[1].set_title('Mask')
    
    axs[2].imshow(image)
    axs[2].imshow(mask, alpha=0.3)
    axs[2].set_title('MRI with mask')
    
    plt.grid(False)
    plt.show()

# %%
for i in range(5):
    plot_images()

# %% [markdown]
# Given the MRI Images of Brain our task is to identify if a tumor is present in the image or not. This problem boils down to image segmentation, which is extensively studied in the field of computer vision. Most popular use case is self driving cars
#
# Above figure shows a sneak peak of what the data looks like. We have Brain MRIs labeled with a mask which indicates the presence of abnormality

# %% [markdown]
# ## Config

# %%
imagePath_df['image-path'] = DataPath + imagePath_df['directory'] + '/' + imagePath_df['images']
imagePath_df['mask-path'] = DataPath + imagePath_df['directory'] + '/' + imagePath_df['masks']

# %%
train , test = train_test_split(imagePath_df, test_size=0.25, random_state=21)

# %%
EPOCHS = 30
BATCH_SIZE = 24
ImgHieght = 256
ImgWidth = 256
Channels = 3

# %% [markdown]
# ## Data Generator

# %%
data_augmentation = dict(rotation_range=0.2,
                        width_shift_range=0.05,
                        height_shift_range=0.05,
                        shear_range=0.05,
                        zoom_range=0.05,
                        horizontal_flip=True,
                        fill_mode='nearest')

# %% [markdown]
# ### Train

# %%
# image generator
imagegen = ImageDataGenerator(rescale=1./255., **data_augmentation)
maskgen = ImageDataGenerator(rescale=1./255., **data_augmentation)


# train generator
timage_generator=imagegen.flow_from_dataframe(dataframe=train,
                                            x_col="image-path",
                                            batch_size= BATCH_SIZE,
                                            seed=42,
                                            class_mode=None,
                                            target_size=(ImgHieght,ImgWidth),
                                            color_mode='rgb')
# validation data generator
tmask_generator=maskgen.flow_from_dataframe(dataframe=train,
                                            x_col="mask-path",
                                            batch_size=BATCH_SIZE,
                                            seed=42,
                                            class_mode=None,
                                            target_size=(ImgHieght,ImgWidth),
                                            color_mode='grayscale')
# Out:
# Found 2946 validated image filenames.
# Found 2946 validated image filenames.

# %% [markdown]
# ### Validation

# %%
# image generator
imagegen = ImageDataGenerator(rescale=1./255.)
maskgen = ImageDataGenerator(rescale=1./255.)


# train generator
vimage_generator=imagegen.flow_from_dataframe(dataframe=test,
                                            x_col="image-path",
                                            batch_size= BATCH_SIZE,
                                            seed=42,
                                            class_mode=None,
                                            target_size=(ImgHieght,ImgWidth),
                                            color_mode='rgb')
# validation data generator
vmask_generator=maskgen.flow_from_dataframe(dataframe=test,
                                            x_col="mask-path",
                                            batch_size=BATCH_SIZE,
                                            seed=42,
                                            class_mode=None,
                                            target_size=(ImgHieght,ImgWidth),
                                            color_mode='grayscale')
# Out:
# Found 983 validated image filenames.
# Found 983 validated image filenames.

# %%
def data_iterator(image_gen, mask_gen):
    for img, mask in zip(image_gen, mask_gen):
        yield img, mask

# %%
train_gen = data_iterator(timage_generator, tmask_generator)
valid_gen = data_iterator(vimage_generator, vmask_generator)

# %% [markdown]
# ## UNet

# %% [markdown]
# UNet is a fully convolutional neural-network. It got its name due to its U-shaped network architecture. It is currently SOTA in the sementic segmentation.
#
# What is semenctic segmentation?
#
# Well its a type of problem studied in computer vision just like image classification, object detection etc.
#
# *  **Image Classification:** We Iddentify what is present in an image. If it is present or not
#
# *  **Object Detection:** We identify what is present in the image and where it is present. Its sometimes also called object localization.
#
# *  **Image Segentation:** In object detection we identify position of an object by labeling a bounding box. In image segmentation we assign each pixel belongs to an image or not. There are two types of Image segmentation: Sementic segmentation and Instance segmentation.following image might help a little bit to visualize difference between these two

# %% [markdown]
# ![](https://miro.medium.com/max/2454/1*cHtBw8yBhprNXj-CBQBx5g.png)

# %% [markdown]
# **Key aspects of UNet:**
#
# *  **Convolution Layers:** Convolution operation are used learn information from images which then can be used as features for mcahine learning problems
#
# *  **Down Sampling:** Sequence of convolution combined with max pooling results in down sampling. In down sampling Size of image is reduced which means we can observe larger portion of image in a single convolution operation. Down sampling is a good approach for identifying what is present in the image. but for identifying where the object is we need to use upsampling.
#
# *  **Up Sampling:** It is just opposite of down sampling. We go from low resolution to high resolution. For up sampling UNet uses transposed covolution which is achieved by taking transpose of filter kernels and reversing the process of convolution. If you want to learn more please check out [this](https://towardsdatascience.com/understanding-semantic-segmentation-with-unet-6be4f42d4b47) and [this](https://naokishibuya.medium.com/up-sampling-with-transposed-convolution-9ae4f2df52d0).

# %% [markdown]
# **Finally we come to UNet Architecture**
#
# Following picture gives a clear picture of What a UNet is. Since there are only convolution layers in this network, therefore its a FCN.

# %% [markdown]
# ![](http://miro.medium.com/max/2400/1*OkUrpDD6I0FpugA_bbYBJQ.png)

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x

# %%
def get_unet(input_img, n_filters=16, dropout=0.1, batchnorm=True):
    """Function to define the UNET Model"""
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size=3, batchnorm=batchnorm)
    print("Shape after c1:", c1.shape)  # Add this line to check shape
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)

    c2 = conv2d_block(p1, n_filters * 2, kernel_size=3, batchnorm=batchnorm)
    print("Shape after c2:", c2.shape)  # Add this line to check shape
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)

    c3 = conv2d_block(p2, n_filters * 4, kernel_size=3, batchnorm=batchnorm)
    print("Shape after c3:", c3.shape)  # Add this line to check shape
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)

    c4 = conv2d_block(p3, n_filters * 8, kernel_size=3, batchnorm=batchnorm)
    print("Shape after c4:", c4.shape)  # Add this line to check shape
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)

    c5 = conv2d_block(p4, n_filters=n_filters * 16, kernel_size=3, batchnorm=batchnorm)
    print("Shape after c5:", c5.shape)  # Add this line to check shape

    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides=(2, 2), padding='same')(c5)
    print("Shape after u6 transpose convolution:", u6.shape)  # Add this line to check shape
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)

    c6 = conv2d_block(u6, n_filters * 8, kernel_size=3, batchnorm=batchnorm)
    print("Shape after c6:", c6.shape)  # Add this line to check shape

    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides=(2, 2), padding='same')(c6)
    print("Shape after u7 transpose convolution:", u7.shape)  # Add this line to check shape
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size=3, batchnorm=batchnorm)
    print("Shape after c7:", c7.shape)  # Add this line to check shape

    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides=(2, 2), padding='same')(c7)
    print("Shape after u8 transpose convolution:", u8.shape)  # Add this line to check shape
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size=3, batchnorm=batchnorm)
    print("Shape after c8:", c8.shape)  # Add this line to check shape

    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides=(2, 2), padding='same')(c8)
    print("Shape after u9 transpose convolution:", u9.shape)  # Add this line to check shape
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size=3, batchnorm=batchnorm)
    print("Shape after c9:", c9.shape)  # Add this line to check shape

    

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
input_img = Input((ImgHieght, ImgWidth, 3), name='img')
model = get_unet(input_img, n_filters=16, dropout=0.2, batchnorm=True)
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])
# Out:
# Shape after c1: (None, 256, 256, 16)
# Shape after c2: (None, 128, 128, 32)
# Shape after c3: (None, 64, 64, 64)
# Shape after c4: (None, 32, 32, 128)
# Shape after c5: (None, 16, 16, 256)
# Shape after u6 transpose convolution: (None, 32, 32, 128)
# Shape after c6: (None, 32, 32, 128)
# Shape after u7 transpose convolution: (None, 64, 64, 64)
# Shape after c7: (None, 64, 64, 64)
# Shape after u8 transpose convolution: (None, 128, 128, 32)
# Shape after c8: (None, 128, 128, 32)
# Shape after u9 transpose convolution: (None, 256, 256, 16)
# Shape after c9: (None, 256, 256, 16)

# %%
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  img (InputLayer)               [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_103 (Conv2D)            (None, 256, 256, 16  448         ['img[0][0]']
#                                 )
#
#  batch_normalization_97 (BatchN  (None, 256, 256, 16  64         ['conv2d_103[0][0]']
#  ormalization)                  )
#
#  activation_97 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_97[0][0]']
#                                 )
#
#  max_pooling2d_24 (MaxPooling2D  (None, 128, 128, 16  0          ['activation_97[0][0]']
#  )                              )
#
#  dropout_42 (Dropout)           (None, 128, 128, 16  0           ['max_pooling2d_24[0][0]']
#                                 )
#
#  conv2d_105 (Conv2D)            (None, 128, 128, 32  4640        ['dropout_42[0][0]']
#                                 )
#
#  batch_normalization_99 (BatchN  (None, 128, 128, 32  128        ['conv2d_105[0][0]']
#  ormalization)                  )
#
#  activation_99 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_99[0][0]']
#                                 )
#
#  max_pooling2d_25 (MaxPooling2D  (None, 64, 64, 32)  0           ['activation_99[0][0]']
#  )
#
#  dropout_43 (Dropout)           (None, 64, 64, 32)   0           ['max_pooling2d_25[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 64, 64, 64)   18496       ['dropout_43[0][0]']
#
#  batch_normalization_101 (Batch  (None, 64, 64, 64)  256         ['conv2d_107[0][0]']
#  Normalization)
#
#  activation_101 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_101[0][0]']
#
#  max_pooling2d_26 (MaxPooling2D  (None, 32, 32, 64)  0           ['activation_101[0][0]']
#  )
#
#  dropout_44 (Dropout)           (None, 32, 32, 64)   0           ['max_pooling2d_26[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 32, 32, 128)  73856       ['dropout_44[0][0]']
#
#  batch_normalization_103 (Batch  (None, 32, 32, 128)  512        ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_103 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_103[0][0]']
#
#  max_pooling2d_27 (MaxPooling2D  (None, 16, 16, 128)  0          ['activation_103[0][0]']
#  )
#
#  dropout_45 (Dropout)           (None, 16, 16, 128)  0           ['max_pooling2d_27[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 16, 16, 256)  295168      ['dropout_45[0][0]']
#
#  batch_normalization_105 (Batch  (None, 16, 16, 256)  1024       ['conv2d_111[0][0]']
#  Normalization)
#
#  activation_105 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_105[0][0]']
#
#  conv2d_transpose_18 (Conv2DTra  (None, 32, 32, 128)  295040     ['activation_105[0][0]']
#  nspose)
#
#  concatenate_18 (Concatenate)   (None, 32, 32, 256)  0           ['conv2d_transpose_18[0][0]',
#                                                                   'activation_103[0][0]']
#
#  dropout_46 (Dropout)           (None, 32, 32, 256)  0           ['concatenate_18[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 32, 32, 128)  295040      ['dropout_46[0][0]']
#
#  batch_normalization_107 (Batch  (None, 32, 32, 128)  512        ['conv2d_113[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_107[0][0]']
#
#  conv2d_transpose_19 (Conv2DTra  (None, 64, 64, 64)  73792       ['activation_107[0][0]']
#  nspose)
#
#  concatenate_19 (Concatenate)   (None, 64, 64, 128)  0           ['conv2d_transpose_19[0][0]',
#                                                                   'activation_101[0][0]']
#
#  dropout_47 (Dropout)           (None, 64, 64, 128)  0           ['concatenate_19[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 64, 64, 64)   73792       ['dropout_47[0][0]']
#
#  batch_normalization_109 (Batch  (None, 64, 64, 64)  256         ['conv2d_115[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_109[0][0]']
#
#  conv2d_transpose_20 (Conv2DTra  (None, 128, 128, 32  18464      ['activation_109[0][0]']
#  nspose)                        )
#
#  concatenate_20 (Concatenate)   (None, 128, 128, 64  0           ['conv2d_transpose_20[0][0]',
#                                 )                                 'activation_99[0][0]']
#
#  dropout_48 (Dropout)           (None, 128, 128, 64  0           ['concatenate_20[0][0]']
#                                 )
#
#  conv2d_117 (Conv2D)            (None, 128, 128, 32  18464       ['dropout_48[0][0]']
#                                 )
#
#  batch_normalization_111 (Batch  (None, 128, 128, 32  128        ['conv2d_117[0][0]']
#  Normalization)                 )
#
#  activation_111 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_111[0][0]']
#                                 )
#
#  conv2d_transpose_21 (Conv2DTra  (None, 256, 256, 16  4624       ['activation_111[0][0]']
#  nspose)                        )
#
#  concatenate_21 (Concatenate)   (None, 256, 256, 32  0           ['conv2d_transpose_21[0][0]',
#                                 )                                 'activation_97[0][0]']
#
#  dropout_49 (Dropout)           (None, 256, 256, 32  0           ['concatenate_21[0][0]']
#                                 )
#
#  conv2d_119 (Conv2D)            (None, 256, 256, 16  4624        ['dropout_49[0][0]']
#                                 )
#
#  batch_normalization_113 (Batch  (None, 256, 256, 16  64         ['conv2d_119[0][0]']
#  Normalization)                 )
#
#  activation_113 (Activation)    (None, 256, 256, 16  0           ['batch_normalization_113[0][0]']
#                                 )
#
#  conv2d_120 (Conv2D)            (None, 256, 256, 1)  17          ['activation_113[0][0]']
#
# ==================================================================================================
# Total params: 1,179,409
# Trainable params: 1,177,937
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=1e-5, verbose=1),
    ModelCheckpoint('model-brain-mri.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
STEP_SIZE_TRAIN = timage_generator.n/BATCH_SIZE
STEP_SIZE_VALID = vimage_generator.n/BATCH_SIZE

# %%
results = model.fit(train_gen,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    callbacks=callbacks,
                    validation_data=valid_gen,
                   validation_steps=STEP_SIZE_VALID)
# Out:
# Epoch 1/30
# 93/92 [==============================] - ETA: 0s - loss: 0.1909 - accuracy: 0.9881
# Epoch 1: val_loss improved from inf to 0.17318, saving model to model-brain-mri.h5
# 92/92 [==============================] - 63s 689ms/step - loss: 0.1909 - accuracy: 0.9881 - val_loss: 0.1732 - val_accuracy: 0.9896 - lr: 0.0010
# Epoch 2/30
# 93/92 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.9898
# Epoch 2: val_loss improved from 0.17318 to 0.11186, saving model to model-brain-mri.h5
# 92/92 [==============================] - 64s 694ms/step - loss: 0.1216 - accuracy: 0.9898 - val_loss: 0.1119 - val_accuracy: 0.9906 - lr: 0.0010
# Epoch 3/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0842 - accuracy: 0.9896
# Epoch 3: val_loss improved from 0.11186 to 0.07779, saving model to model-brain-mri.h5
# 92/92 [==============================] - 64s 695ms/step - loss: 0.0842 - accuracy: 0.9896 - val_loss: 0.0778 - val_accuracy: 0.9894 - lr: 0.0010
# Epoch 4/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0611 - accuracy: 0.9918
# Epoch 4: val_loss improved from 0.07779 to 0.05035, saving model to model-brain-mri.h5
# 92/92 [==============================] - 65s 708ms/step - loss: 0.0611 - accuracy: 0.9918 - val_loss: 0.0504 - val_accuracy: 0.9940 - lr: 0.0010
# Epoch 5/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9923
# Epoch 5: val_loss improved from 0.05035 to 0.04312, saving model to model-brain-mri.h5
# 92/92 [==============================] - 64s 702ms/step - loss: 0.0484 - accuracy: 0.9923 - val_loss: 0.0431 - val_accuracy: 0.9937 - lr: 0.0010
# Epoch 6/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0384 - accuracy: 0.9930
# Epoch 6: val_loss improved from 0.04312 to 0.03568, saving model to model-brain-mri.h5
# 92/92 [==============================] - 64s 701ms/step - loss: 0.0384 - accuracy: 0.9930 - val_loss: 0.0357 - val_accuracy: 0.9938 - lr: 0.0010
# Epoch 7/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9934
# Epoch 7: val_loss improved from 0.03568 to 0.02930, saving model to model-brain-mri.h5
# 92/92 [==============================] - 65s 715ms/step - loss: 0.0326 - accuracy: 0.9934 - val_loss: 0.0293 - val_accuracy: 0.9945 - lr: 0.0010
# Epoch 8/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9938
# Epoch 8: val_loss improved from 0.02930 to 0.02358, saving model to model-brain-mri.h5
# 92/92 [==============================] - 64s 700ms/step - loss: 0.0283 - accuracy: 0.9938 - val_loss: 0.0236 - val_accuracy: 0.9949 - lr: 0.0010
# Epoch 9/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.9937
# Epoch 9: val_loss did not improve from 0.02358
# 92/92 [==============================] - 64s 694ms/step - loss: 0.0258 - accuracy: 0.9937 - val_loss: 0.0259 - val_accuracy: 0.9948 - lr: 0.0010
# Epoch 10/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0243 - accuracy: 0.9935
# Epoch 10: val_loss improved from 0.02358 to 0.02216, saving model to model-brain-mri.h5
# 92/92 [==============================] - 63s 693ms/step - loss: 0.0243 - accuracy: 0.9935 - val_loss: 0.0222 - val_accuracy: 0.9949 - lr: 0.0010
# Epoch 11/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9941
# Epoch 11: val_loss improved from 0.02216 to 0.02026, saving model to model-brain-mri.h5
# 92/92 [==============================] - 64s 697ms/step - loss: 0.0212 - accuracy: 0.9941 - val_loss: 0.0203 - val_accuracy: 0.9949 - lr: 0.0010
# Epoch 12/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9941
# Epoch 12: val_loss did not improve from 0.02026
# 92/92 [==============================] - 63s 693ms/step - loss: 0.0203 - accuracy: 0.9941 - val_loss: 0.0224 - val_accuracy: 0.9950 - lr: 0.0010
# Epoch 13/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9943
# Epoch 13: val_loss did not improve from 0.02026
# 92/92 [==============================] - 64s 697ms/step - loss: 0.0188 - accuracy: 0.9943 - val_loss: 0.0216 - val_accuracy: 0.9946 - lr: 0.0010
# Epoch 14/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9944
# Epoch 14: val_loss improved from 0.02026 to 0.01645, saving model to model-brain-mri.h5
# 92/92 [==============================] - 63s 694ms/step - loss: 0.0176 - accuracy: 0.9944 - val_loss: 0.0164 - val_accuracy: 0.9953 - lr: 0.0010
# Epoch 15/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.9946
# Epoch 15: val_loss improved from 0.01645 to 0.01505, saving model to model-brain-mri.h5
# 92/92 [==============================] - 64s 697ms/step - loss: 0.0169 - accuracy: 0.9946 - val_loss: 0.0151 - val_accuracy: 0.9957 - lr: 0.0010
# Epoch 16/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9948
# Epoch 16: val_loss improved from 0.01505 to 0.01358, saving model to model-brain-mri.h5
# 92/92 [==============================] - 63s 685ms/step - loss: 0.0160 - accuracy: 0.9948 - val_loss: 0.0136 - val_accuracy: 0.9958 - lr: 0.0010
# Epoch 17/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 0.9948
# Epoch 17: val_loss did not improve from 0.01358
# 92/92 [==============================] - 63s 692ms/step - loss: 0.0152 - accuracy: 0.9948 - val_loss: 0.0140 - val_accuracy: 0.9959 - lr: 0.0010
# Epoch 18/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9951
# Epoch 20: val_loss improved from 0.01242 to 0.01235, saving model to model-brain-mri.h5
# 92/92 [==============================] - 64s 696ms/step - loss: 0.0132 - accuracy: 0.9951 - val_loss: 0.0123 - val_accuracy: 0.9959 - lr: 0.0010
# Epoch 21/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9950
# Epoch 21: val_loss improved from 0.01235 to 0.01169, saving model to model-brain-mri.h5
# 92/92 [==============================] - 64s 699ms/step - loss: 0.0133 - accuracy: 0.9950 - val_loss: 0.0117 - val_accuracy: 0.9962 - lr: 0.0010
# Epoch 22/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9955
# Epoch 22: val_loss did not improve from 0.01169
# 92/92 [==============================] - 64s 696ms/step - loss: 0.0120 - accuracy: 0.9955 - val_loss: 0.0119 - val_accuracy: 0.9961 - lr: 0.0010
# Epoch 23/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9955
# Epoch 23: val_loss did not improve from 0.01169
# 92/92 [==============================] - 63s 692ms/step - loss: 0.0118 - accuracy: 0.9955 - val_loss: 0.0124 - val_accuracy: 0.9962 - lr: 0.0010
# Epoch 24/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9954
# Epoch 24: val_loss did not improve from 0.01169
# 92/92 [==============================] - 63s 684ms/step - loss: 0.0120 - accuracy: 0.9954 - val_loss: 0.0136 - val_accuracy: 0.9957 - lr: 0.0010
# Epoch 25/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9954
# Epoch 25: val_loss improved from 0.01169 to 0.00914, saving model to model-brain-mri.h5
# 92/92 [==============================] - 66s 719ms/step - loss: 0.0117 - accuracy: 0.9954 - val_loss: 0.0091 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 26/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9955
# Epoch 26: val_loss did not improve from 0.00914
# 92/92 [==============================] - 63s 692ms/step - loss: 0.0112 - accuracy: 0.9955 - val_loss: 0.0162 - val_accuracy: 0.9953 - lr: 0.0010
# Epoch 27/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9954
# Epoch 27: val_loss did not improve from 0.00914
# 92/92 [==============================] - 65s 705ms/step - loss: 0.0116 - accuracy: 0.9954 - val_loss: 0.0129 - val_accuracy: 0.9959 - lr: 0.0010
# Epoch 28/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9961
# Epoch 28: val_loss did not improve from 0.00914
# 92/92 [==============================] - 63s 692ms/step - loss: 0.0096 - accuracy: 0.9961 - val_loss: 0.0105 - val_accuracy: 0.9965 - lr: 0.0010
# Epoch 29/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9959
# Epoch 29: val_loss did not improve from 0.00914
# 92/92 [==============================] - 64s 697ms/step - loss: 0.0100 - accuracy: 0.9959 - val_loss: 0.0119 - val_accuracy: 0.9961 - lr: 0.0010
# Epoch 30/30
# 93/92 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9959
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 30: val_loss did not improve from 0.00914
# 92/92 [==============================] - 64s 695ms/step - loss: 0.0097 - accuracy: 0.9959 - val_loss: 0.0103 - val_accuracy: 0.9966 - lr: 0.0010

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss", color=sns.xkcd_rgb['greenish teal'])
plt.plot(results.history["val_loss"], label="val_loss", color=sns.xkcd_rgb['amber'])
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend()
# plt.grid(False)
plt.show()

# %%
from tensorflow.keras.models import load_model, save_model

# Assuming 'model' is your trained model
model.save('model-brain-mri.h5')  # Save the model as an HDF5 file

# %% [markdown]
# ## Prediction

# %%
# load the best model
model.load_weights('model-brain-mri.h5')

# %%
eval_results = model.evaluate(valid_gen, steps=STEP_SIZE_VALID, verbose=1)
# Out:
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0113 - accuracy: 0.9963

# %%
for i in range(10):
    idx = np.random.randint(0, len(imagePath_df))
    
    imagePath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['images'].iloc[idx])
    maskPath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['masks'].iloc[idx])
    
    image = cv2.imread(imagePath)
    mask = cv2.imread(maskPath)
    
    img = cv2.resize(image ,(ImgHieght, ImgWidth))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,4,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,4,2)
    plt.imshow(mask)
    plt.title('Original Mask')
    plt.subplot(1,4,3)
    plt.imshow(np.squeeze(pred))
    plt.title('Prediction')
    plt.subplot(1,4,4)
    plt.imshow(np.squeeze(pred) > 0.5)
    plt.title('BinaryPrediction')
    plt.show()
# Out:
# 1/1 [==============================] - 1s 852ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
